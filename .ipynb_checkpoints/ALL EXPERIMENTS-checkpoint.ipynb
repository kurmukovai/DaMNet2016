# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.metrics.pairwise import euclidean_distances
from sklearn.metrics import roc_auc_score

from load_data import load_apoe
from clustering_base import NewmanEig, FastGreedy, CommunityLouvian, metric_adj
from model_evaluation import SVC_grid_search, SVC_score, exp_kernel
import time

# %%
path = 'UCLA_APOE_matrices/'
data, target, centers = load_apoe(path)
# Out:
# UCLA APOE data shape                   : (55, 110, 110)
# UCLA APOE target variable shape        : (55,)

# %%
distances = euclidean_distances(centers)

# %%
weighted_data = np.nan_to_num(data / distances)
binarized_data = data.copy()
binarized_data[data > 0] = 1

# %%
plt.figure(figsize=(12,12))
plt.subplot(2,2,1)
plt.imshow(data[1], )
plt.title('Original adjacency matrix, id = 1')
plt.subplot(2,2,2)
plt.imshow(binarized_data[1], )
plt.title('Binarized adjacency matrix, id = 1')
plt.subplot(2,2,3)
plt.imshow(weighted_data[1], )
plt.title('Weighted on euclidean distance adjacency matrix, id = 1',)# fontsize = 12)

# %%
partition_w_ne = NewmanEig(weighted_data)
partition_b_ne = NewmanEig(binarized_data)

partition_w_fg = FastGreedy(weighted_data)
partition_b_fg = FastGreedy(binarized_data)

partition_w_l  = CommunityLouvian(weighted_data)
partition_b_l  = CommunityLouvian(binarized_data)

# %%
names = ['newman_w', 'newman_b', 'fastgreedy_w', 'fastgreedy_b', 'louvain_w', 'louvain_b']
partitions = [partition_w_ne, partition_b_ne, partition_w_fg, partition_b_fg, partition_w_l, partition_b_l ]
partitions = dict(zip(names, partitions))

# %%
ari, ami = {}, {}

for alg, part in partitions.items():
    start = time.time()
    ari[alg], ami[alg] = metric_adj(part, mode='both')
    #print(alg, '{:3f}'.format(time.time() - start))

# %%
plt.figure(figsize=(15,8))
i = 1
#kernel = np.zeros((55, 55))
for alg, sim in ari.items():
    plt.subplot(2, 3, i)
    i += 1
    plt.imshow(1 - sim)
    plt.title(alg)
    #kernel += (1 - sim)**2

# %%
from sklearn.cross_validation import StratifiedKFold
from sklearn import svm
# Out:
# /home/anvar/anaconda3/lib/python3.5/site-packages/sklearn/cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def repeatSVM(gram_matrix, target_vector, n_folds=10,
             n_repetitions=50, penalty=1, LOO=False):
    '''
    This function computes ROC AUC values of SVM with precomputed
    kernel over several runs of k-fold cross-validation

    Accepts:
    gram_matrix - precomputed Gram matrix
    target_vector - target vector of class labels
    n_folds - number of folds for cross-validation
    n_repetitions - number of repetitions of k-fold
                   cross-validation procedure (with random splitting into folds)
    penalty - parameter C of the sklearn.svm.SVC
             (penalty parameter of the error term)
    Returns:
    roc_auc - list of length n_repetitions wherein each
             value is a ROC AUC based on aggregated over folds prediction.
    decisions - list of length n_repetitions wherein each element
               is an array of the respective aggragated outputs of
               the decision function
    Note: decision function output is used for prediction
         to avoid problems with Platt calibration in SVM predict_proba
    '''
    X, y = gram_matrix, np.array(target_vector)
    clf = svm.SVC(C=penalty, kernel='precomputed', random_state=0)
    overall_roc_auc = []
    overall_decisions = []
    # overall_predict_proba = []
    overall_predict = np.zeros(55)

    roc_c = []

    for rep in range(0, n_repetitions):
        if LOO is not True:
            CV = StratifiedKFold(target_vector, n_folds,
                                shuffle=True, random_state=rep)
        else:
            CV = LeaveOneOut(y.shape[0])
        decision_predicted = np.zeros(y.shape[0])
        metrics_dict = {'ROC curve': []}
        for train, test in CV:
            clf.fit(X[train][:, train], y[train])
            decision_output = clf.decision_function(X[test][:, train])
            decision_predicted[test] = decision_output
            # predicted_proba = clf.predicted_proba(X[test][:, train])
            predicted = clf.predict(X[test][:, train])

            #metrics_dict['ROC curve'].append(
            #    roc_curve(y[test], decision_output))
            #roc_c.append(metrics_dict)

        roc_auc_value = roc_auc_score(y, decision_predicted)
        overall_roc_auc.append(roc_auc_value)
        overall_decisions.append(decision_predicted)
        # overall_predict_proba.append(predicted_proba)
        overall_predict[test] = predicted
    # , np.array(overall_predict_proba)
    return np.array(overall_roc_auc), np.array(overall_decisions), np.array(overall_predict)#, roc_c

# %%
params = [0.01, 0.1, 0.3, 0.5, 0.7, 0.9] + list(range(1, 15))
penalties = [0.1, 1, 5, 10, 50]

for param in params:
    for penalty in penalties:
        kernel = exp_kernel(ari['louvain_w'], param)
        auc, _, _ = repeatSVM(kernel, target, penalty = penalty)
        print('Kernel parameter : {}, SVM parameter : {}, resulting auc :{:3f} +- {:3f}'.format(
                param, penalty, auc.mean(), auc.std()))
# Out:
# Kernel parameter : 0.01, SVM parameter : 0.1, resulting auc :0.598187 +- 0.026138
# Kernel parameter : 0.01, SVM parameter : 1, resulting auc :0.596987 +- 0.026043
# Kernel parameter : 0.01, SVM parameter : 5, resulting auc :0.595733 +- 0.025119
# Kernel parameter : 0.01, SVM parameter : 10, resulting auc :0.595760 +- 0.024927
# Kernel parameter : 0.01, SVM parameter : 50, resulting auc :0.595707 +- 0.024973
# Kernel parameter : 0.1, SVM parameter : 0.1, resulting auc :0.598400 +- 0.025328
# Kernel parameter : 0.1, SVM parameter : 1, resulting auc :0.597120 +- 0.024921
# Kernel parameter : 0.1, SVM parameter : 5, resulting auc :0.597067 +- 0.024715
# Kernel parameter : 0.1, SVM parameter : 10, resulting auc :0.597307 +- 0.024715
# Kernel parameter : 0.1, SVM parameter : 50, resulting auc :0.579413 +- 0.032071
# Kernel parameter : 0.3, SVM parameter : 0.1, resulting auc :0.600133 +- 0.025129
# Kernel parameter : 0.3, SVM parameter : 1, resulting auc :0.599733 +- 0.024722
# Kernel parameter : 0.3, SVM parameter : 5, resulting auc :0.613707 +- 0.026474
# Kernel parameter : 0.3, SVM parameter : 10, resulting auc :0.606480 +- 0.033169
# Kernel parameter : 0.3, SVM parameter : 50, resulting auc :0.588907 +- 0.030623
# Kernel parameter : 0.5, SVM parameter : 0.1, resulting auc :0.602880 +- 0.024802
# Kernel parameter : 0.5, SVM parameter : 1, resulting auc :0.602853 +- 0.024459
# Kernel parameter : 0.5, SVM parameter : 5, resulting auc :0.626880 +- 0.030304
# Kernel parameter : 0.5, SVM parameter : 10, resulting auc :0.600693 +- 0.032699
# Kernel parameter : 0.5, SVM parameter : 50, resulting auc :0.601440 +- 0.029693
# Kernel parameter : 0.7, SVM parameter : 0.1, resulting auc :0.605253 +- 0.025341
# Kernel parameter : 0.7, SVM parameter : 1, resulting auc :0.604933 +- 0.025121
# Kernel parameter : 0.7, SVM parameter : 5, resulting auc :0.611707 +- 0.032296
# Kernel parameter : 0.7, SVM parameter : 10, resulting auc :0.618267 +- 0.030943
# Kernel parameter : 0.7, SVM parameter : 50, resulting auc :0.612160 +- 0.029183
# Kernel parameter : 0.9, SVM parameter : 0.1, resulting auc :0.607120 +- 0.026088
# Kernel parameter : 0.9, SVM parameter : 1, resulting auc :0.607120 +- 0.026145
# Kernel parameter : 0.9, SVM parameter : 5, resulting auc :0.614720 +- 0.031721
# Kernel parameter : 0.9, SVM parameter : 10, resulting auc :0.624507 +- 0.029496
# Kernel parameter : 0.9, SVM parameter : 50, resulting auc :0.622293 +- 0.028157
# Kernel parameter : 1, SVM parameter : 0.1, resulting auc :0.607947 +- 0.025705
# Kernel parameter : 1, SVM parameter : 1, resulting auc :0.607813 +- 0.025880
# Kernel parameter : 1, SVM parameter : 5, resulting auc :0.621253 +- 0.031894
# Kernel parameter : 1, SVM parameter : 10, resulting auc :0.625467 +- 0.028736
# Kernel parameter : 1, SVM parameter : 50, resulting auc :0.626613 +- 0.028413
# Kernel parameter : 2, SVM parameter : 0.1, resulting auc :0.618320 +- 0.024917
# Kernel parameter : 2, SVM parameter : 1, resulting auc :0.619040 +- 0.025099
# Kernel parameter : 2, SVM parameter : 5, resulting auc :0.653280 +- 0.027308
# Kernel parameter : 2, SVM parameter : 10, resulting auc :0.655520 +- 0.027288
# Kernel parameter : 2, SVM parameter : 50, resulting auc :0.655520 +- 0.027288
# Kernel parameter : 3, SVM parameter : 0.1, resulting auc :0.628160 +- 0.026621
# Kernel parameter : 3, SVM parameter : 1, resulting auc :0.636107 +- 0.026786
# Kernel parameter : 3, SVM parameter : 5, resulting auc :0.671147 +- 0.025093
# Kernel parameter : 3, SVM parameter : 10, resulting auc :0.671147 +- 0.025093
# Kernel parameter : 3, SVM parameter : 50, resulting auc :0.671147 +- 0.025093
# Kernel parameter : 4, SVM parameter : 0.1, resulting auc :0.635573 +- 0.028261
# Kernel parameter : 4, SVM parameter : 1, resulting auc :0.648800 +- 0.028367
# Kernel parameter : 4, SVM parameter : 5, resulting auc :0.680907 +- 0.024589
# Kernel parameter : 4, SVM parameter : 10, resulting auc :0.680907 +- 0.024589
# Kernel parameter : 4, SVM parameter : 50, resulting auc :0.680907 +- 0.024589
# Kernel parameter : 5, SVM parameter : 0.1, resulting auc :0.642800 +- 0.029654
# Kernel parameter : 5, SVM parameter : 1, resulting auc :0.655067 +- 0.029317
# Kernel parameter : 5, SVM parameter : 5, resulting auc :0.687147 +- 0.026036
# Kernel parameter : 5, SVM parameter : 10, resulting auc :0.687147 +- 0.026036
# Kernel parameter : 5, SVM parameter : 50, resulting auc :0.687147 +- 0.026036
# Kernel parameter : 6, SVM parameter : 0.1, resulting auc :0.649947 +- 0.030084
# Kernel parameter : 6, SVM parameter : 1, resulting auc :0.660160 +- 0.030766
# Kernel parameter : 6, SVM parameter : 5, resulting auc :0.691360 +- 0.027387
# Kernel parameter : 6, SVM parameter : 10, resulting auc :0.691360 +- 0.027387
# Kernel parameter : 6, SVM parameter : 50, resulting auc :0.691360 +- 0.027387
# Kernel parameter : 7, SVM parameter : 0.1, resulting auc :0.659173 +- 0.032147
# Kernel parameter : 7, SVM parameter : 1, resulting auc :0.666347 +- 0.032225
# Kernel parameter : 7, SVM parameter : 5, resulting auc :0.695093 +- 0.028930
# Kernel parameter : 7, SVM parameter : 10, resulting auc :0.695093 +- 0.028930
# Kernel parameter : 7, SVM parameter : 50, resulting auc :0.695093 +- 0.028930
# Kernel parameter : 8, SVM parameter : 0.1, resulting auc :0.666720 +- 0.033875
# Kernel parameter : 8, SVM parameter : 1, resulting auc :0.670613 +- 0.033725
# Kernel parameter : 8, SVM parameter : 5, resulting auc :0.696907 +- 0.030756
# Kernel parameter : 8, SVM parameter : 10, resulting auc :0.696907 +- 0.030756
# Kernel parameter : 8, SVM parameter : 50, resulting auc :0.696907 +- 0.030756
# Kernel parameter : 9, SVM parameter : 0.1, resulting auc :0.671413 +- 0.034766
# Kernel parameter : 9, SVM parameter : 1, resulting auc :0.672533 +- 0.034951
# Kernel parameter : 9, SVM parameter : 5, resulting auc :0.696347 +- 0.031698
# Kernel parameter : 9, SVM parameter : 10, resulting auc :0.696347 +- 0.031698
# Kernel parameter : 9, SVM parameter : 50, resulting auc :0.696347 +- 0.031698
# Kernel parameter : 10, SVM parameter : 0.1, resulting auc :0.672053 +- 0.033425
# Kernel parameter : 10, SVM parameter : 1, resulting auc :0.672240 +- 0.033428
# Kernel parameter : 10, SVM parameter : 5, resulting auc :0.694293 +- 0.031671
# Kernel parameter : 10, SVM parameter : 10, resulting auc :0.694293 +- 0.031671
# Kernel parameter : 10, SVM parameter : 50, resulting auc :0.694293 +- 0.031671
# Kernel parameter : 11, SVM parameter : 0.1, resulting auc :0.666773 +- 0.033142
# Kernel parameter : 11, SVM parameter : 1, resulting auc :0.666613 +- 0.033143
# Kernel parameter : 11, SVM parameter : 5, resulting auc :0.689467 +- 0.031603
# Kernel parameter : 11, SVM parameter : 10, resulting auc :0.689467 +- 0.031603
# Kernel parameter : 11, SVM parameter : 50, resulting auc :0.689467 +- 0.031603
# Kernel parameter : 12, SVM parameter : 0.1, resulting auc :0.657387 +- 0.033357
# Kernel parameter : 12, SVM parameter : 1, resulting auc :0.657333 +- 0.033390
# Kernel parameter : 12, SVM parameter : 5, resulting auc :0.683600 +- 0.031473
# Kernel parameter : 12, SVM parameter : 10, resulting auc :0.683600 +- 0.031473
# Kernel parameter : 12, SVM parameter : 50, resulting auc :0.683600 +- 0.031473
# Kernel parameter : 13, SVM parameter : 0.1, resulting auc :0.640880 +- 0.031684
# Kernel parameter : 13, SVM parameter : 1, resulting auc :0.640773 +- 0.031765
# Kernel parameter : 13, SVM parameter : 5, resulting auc :0.675387 +- 0.031281
# Kernel parameter : 13, SVM parameter : 10, resulting auc :0.675387 +- 0.031281
# Kernel parameter : 13, SVM parameter : 50, resulting auc :0.675387 +- 0.031281
# Kernel parameter : 14, SVM parameter : 0.1, resulting auc :0.622320 +- 0.031386
# Kernel parameter : 14, SVM parameter : 1, resulting auc :0.622187 +- 0.031148
# Kernel parameter : 14, SVM parameter : 5, resulting auc :0.663360 +- 0.031862
# Kernel parameter : 14, SVM parameter : 10, resulting auc :0.663360 +- 0.031862
# Kernel parameter : 14, SVM parameter : 50, resulting auc :0.663360 +- 0.031862

# %%
kernel = exp_kernel(ari['louvain_w'], 8)
auc, dec, pred = repeatSVM(kernel, target,n_repetitions=100, penalty = 5)

# %%
auc.mean()
# Out:
# 0.69192000000000009

# %%
# params = [0.01, 0.1, 0.3, 0.5, 0.7, 0.9] + list(range(1, 11))
# penalties = [0.1, 1, 5, 10, 50]

# res_ari = {}
# res_ami = {}

# for alg, sim in ari.items():

#     best_params, _, _ =  SVC_grid_search(ari[alg], target, range(55),
#                                          5, params, penalties, random_state = 100)
    
#     res_ari[alg] = SVC_score(ari[alg], target, range(55),
#                              param=best_params['Kernel Parameter'],
#                              penalty=best_params['SVC Parameter'], random_state = 100)
    
            
#     print('ARI', alg, 'param = {}, penalty = {}, mean_auc = {:3f}, std_auc = {:3f}'.format(best_params['Kernel Parameter'],
#                                                                                           best_params['SVC Parameter'],
#                                                                                           res_ari[alg].mean(),
#                                                                                           res_ari[alg].std()))
    
#     best_params, _, _ =  SVC_grid_search(ami[alg], target, range(55),
#                                          5, params, penalties, random_state = 100)
    
#     res_ami[alg] = SVC_score(ami[alg], target, range(55),
#                              param=best_params['Kernel Parameter'],
#                              penalty=best_params['SVC Parameter'], random_state = 100)
    
#     print('AMI', alg, 'param = {}, penalty = {}, mean_auc = {:3f}, std_auc = {:3f}'.format(best_params['Kernel Parameter'],
#                                                                                           best_params['SVC Parameter'],
#                                                                                           res_ami[alg].mean(),
#                                                                                           res_ami[alg].std()))
